# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('C:/Users/Lenovo/Desktop/image.jpg')

# %%
cv2.imshow('input',image)
cv2.waitKey(0)  # delay 0
cv2.destroyAllWindows()

# %%
plt.figure()
plt.imshow(image)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Input size is: (551, 979, 3)

# %%
print('Input size is:', image.shape)
# Out:
# Input size is: (551, 979, 3)

# %%
r=image[:,:,0]
plt.figure()
plt.imshow(r,cmap="gray")
plt.title('red')
# Out:
# Text(0.5, 1.0, 'red')

# %%
g=image[:,:,1]
plt.figure()
plt.imshow(g,cmap="gray")
plt.title('green')
# Out:
# Text(0.5, 1.0, 'green')

# %%
b=image[:,:,2]
plt.figure()
plt.imshow(b,cmap="gray")
plt.title('blue')
# Out:
# Text(0.5, 1.0, 'blue')

# %%
cv2.imshow('input', image)
cv2.imshow('red', r)
cv2.imshow('green', g)
cv2.imshow('blue', b)
cv2.waitKey(0)  # delay 0
cv2.destroyAllWindows()

# %%
im_resize = cv2.resize(b, (256, 256))
print('blue image', im_resize.shape)
# Out:
# blue image (256, 256)

# %%
img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure()
plt.imshow(img,cmap='gray')
plt.show()

# %%
ret, bw_img = cv2.threshold(r, 127, 255, cv2.THRESH_BINARY)
plt.figure()
plt.imshow(bw_img,cmap="gray")
